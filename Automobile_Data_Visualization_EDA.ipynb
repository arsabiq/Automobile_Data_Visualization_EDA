# %%
import numpy as np
import pandas as pd
# basic visualization package - bar, line, pie, scatter, histogram
import matplotlib.pyplot as plt
# discriptive plots - kde, box, heatmap
import seaborn as sns

# %%
auto_price = pd.read_csv("https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/Automobile_price_data__Raw_.csv")

# %%
auto_price.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
auto_price.drop(['symboling','normalized-losses'], axis = 1, inplace = True)

# %%
# replace '?' by np.nan
auto_df = auto_price.replace('?', np.nan)

# %%
auto_df.isnull().sum()
# Out:
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
# drop the rows with missing data 
auto_df.dropna(inplace = True)

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193 entries, 0 to 204
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               193 non-null    object
#  1   fuel-type          193 non-null    object
#  2   aspiration         193 non-null    object
#  3   num-of-doors       193 non-null    object
#  4   body-style         193 non-null    object
#  5   drive-wheels       193 non-null    object
#  6   engine-location    193 non-null    object
#  7   wheel-base         193 non-null    float64
#  8   length             193 non-null    float64
#  9   width              193 non-null    float64
#  10  height             193 non-null    float64
#  11  curb-weight        193 non-null    int64
#  12  engine-type        193 non-null    object
#  13  num-of-cylinders   193 non-null    object
#  14  engine-size        193 non-null    int64
#  15  fuel-system        193 non-null    object
# ...

# %%
cols = ['bore','stroke','horsepower','peak-rpm','price']
auto_df[cols] = auto_df[cols].apply(pd.to_numeric)

# %% [markdown]
# ##### Line Plot
#     * Univariate or Bivariate (Relationship Plot)
#     * Trend Analysis (Time Series) - Univariate Analysis

# %%
auto_df['price'].sort_values().unique()
# Out:
# array([ 5118,  5151,  5195,  5348,  5389,  5399,  5499,  5572,  6095,
#         6189,  6229,  6295,  6338,  6377,  6479,  6488,  6529,  6575,
#         6649,  6669,  6692,  6695,  6785,  6795,  6849,  6855,  6918,
#         6938,  6989,  7053,  7099,  7126,  7129,  7198,  7295,  7299,
#         7349,  7395,  7463,  7499,  7603,  7609,  7689,  7738,  7775,
#         7788,  7799,  7895,  7898,  7957,  7975,  7995,  7999,  8013,
#         8058,  8189,  8195,  8238,  8249,  8358,  8449,  8495,  8499,
#         8778,  8845,  8921,  8948,  8949,  9095,  9233,  9258,  9279,
#         9298,  9495,  9538,  9549,  9639,  9959,  9960,  9980,  9988,
#         9989,  9995, 10198, 10245, 10295, 10345, 10595, 10698, 10898,
#        11048, 11199, 11245, 11248, 11259, 11549, 11595, 11694, 11850,
#        11900, 12170, 12290, 12440, 12629, 12764, 12940, 12945, 12964,
#        13200, 13295, 13415, 13495, 13499, 13845, 13860, 13950, 14399,
# ...

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (10,6))
plt.plot(auto_df['price'].sort_values().unique())
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (10,6))
plt.plot(auto_df.sort_values(by = 'price')['price'], auto_df.sort_values(by = 'price')['city-mpg'],color = 'darkviolet')
plt.title('Price vs City Mileage')
plt.xlabel('Price')
plt.ylabel('City Mileage')
plt.show()

# %% [markdown]
#     * Interpretation: With Increase in vehicle price there is decrease in mileage.

# %% [markdown]
# #### Bar Plot
#     * Bivariate / Univariate Analysis
#     * Bar chart used by Categorical, Nominal, Categorical vs Value Counts/Numerical/Continious
#     * Bar Plots are used to display counts (.value_counts()) of unique value for categorical dtype, Height of Bar represents count for each category.

# %%
auto_df[['price']].loc[10:75,].plot.bar(figsize = (12,6),color = 'deepskyblue')
# Out:
# <Axes: >

# %%
auto_df['make'].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# mazda            12
# volvo            11
# peugot           11
# bmw               8
# dodge             8
# mercedes-benz     8
# plymouth          7
# saab              6
# audi              6
# porsche           4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# isuzu             2
# mercury           1
# Name: count, dtype: int64

# %%
auto_df['make'].value_counts().plot.bar(figsize = (10,6))
# Out:
# <Axes: xlabel='make'>

# %% [markdown]
# ##### Histogram
#
#     * Continious Samples - Study the spread / distribution of Data
#     * Univariate Analysis.

# %%
plt.figure(figsize = (9,5))
# bins = num of intervals
# Price of vehicle is positively skewed
plt.hist(auto_df['price'], color = 'orange', bins = 10)
plt.title('Histogram Plot - Auto Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Distribution Plot
#
#     * Histogram + KDE
#     * Probability Density Function (PDF) -> Continious

# %%
import warnings
warnings.filterwarnings('ignore')

fig = plt.figure(figsize = (9,6))
sns.distplot(auto_df['engine-size'], bins = 10, color = 'blue')
plt.show()

# %%
fig = plt.figure(figsize = (9,6))
# hist = False => KDE Plot
sns.distplot(auto_df['engine-size'], bins = 10, color = 'blue', hist = False)
plt.show()

# %% [markdown]
# #### Scatter Plot
#
#     * Scatter Plots is plotted between numerical values.
#     * It shows relationship b/w x & y plots
#     * Bivariate Analysis.

# %%
plt.style.use('seaborn-whitegrid')
fig = plt.figure(figsize = (9,6))
# marker = shape of scatter plot 's','*','d','^','>','<','o','.'
# alpha = color transperancy
sns.scatterplot(x = auto_df['city-mpg'], y = auto_df['price'], color = 'deepskyblue', marker = 's', alpha = 0.6)
plt.show()

# %% [markdown]
# #### Pie-Chart

# %%
auto_df['make'].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# mazda            12
# volvo            11
# peugot           11
# bmw               8
# dodge             8
# mercedes-benz     8
# plymouth          7
# saab              6
# audi              6
# porsche           4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# isuzu             2
# mercury           1
# Name: count, dtype: int64

# %%
plt.style.use('ggplot')
plt.figure(figsize = (6,6))
# autopct = compute percentage %
plt.pie(auto_df['make'].value_counts(), labels = auto_df['make'].value_counts().index, autopct = '%0.0f%%')
plt.show()

# %% [markdown]
# ###### BoxPlot
#     * Distribution of Continious Data
#     * It shows statistical distribution like - Quartiles (Q1, Q2, Q3) and Median (50% or Q2).
#     * This plot is useful in showing Outliers.

# %%
plt.figure(figsize = (7,3))
# orient = 'h' , 'h' -> Horizontal Orientation
sns.boxplot(auto_df['price'], orient = 'h')
plt.show()
